# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
card= pd.read_excel('card transactions.xlsx')
card = card[card['Transtype']=='P'] #We only study the Transtype P here
card.head()
# Out:
#    Recnum     Cardnum       Date       Merchnum        Merch description  \
# 0       1  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
# 1       2  5142183973 2010-01-01    61003026333  SERVICE MERCHANDISE #81
# 2       3  5142131721 2010-01-01  4503082993600        OFFICE DEPOT #191
# 3       4  5142148452 2010-01-01  5509006296254   FEDEX SHP 12/28/09 AB#
# 4       5  5142190439 2010-01-01  5509006296254   FEDEX SHP 12/23/09 AB#
#
#   Merch state  Merch zip Transtype  Amount  Fraud
# 0          TN    38118.0         P    3.62      0
# 1          MA     1803.0         P   31.42      0
# 2          MD    20706.0         P  178.49      0
# 3          TN    38118.0         P    3.62      0
# 4          TN    38118.0         P    3.62      0

# %% [markdown]
# ## Fill in Missing Values

# %%
card.info() #There are NAs in Merch state, Merch zip
## We don't want to study Merchnum, since this field and Merch description are both unique identifier for merchants
## while Merch description doesn't have NAs.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96398 entries, 0 to 96752
# Data columns (total 10 columns):
# Recnum               96398 non-null int64
# Cardnum              96398 non-null int64
# Date                 96398 non-null datetime64[ns]
# Merchnum             93199 non-null object
# Merch description    96398 non-null object
# Merch state          95377 non-null object
# Merch zip            92097 non-null float64
# Transtype            96398 non-null object
# Amount               96398 non-null float64
# Fraud                96398 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 8.1+ MB

# %%
## Add values into zip by major corresponding values group by merch description, new field is zip_x
merNum_Des = card.dropna(axis=0).groupby('Merch description').agg({'Merch zip':lambda x:x.value_counts().index[0]})
newcard = card.merge(merNum_Des,right_index=True,left_on='Merch description',how='left')
newcard['Merch zip_x'].fillna(newcard['Merch zip_y'],inplace=True)

# %%
## Add values into zip by major corresponding values group by cardnum, new field is zip_x_x
merNum_Des = newcard.dropna(axis=0).groupby('Cardnum').agg({'Merch zip_x':lambda x:x.value_counts().index[0]})
newcard = newcard.merge(merNum_Des,right_index=True,left_on='Cardnum',how='left')
newcard['Merch zip_x_x'].fillna(newcard['Merch zip_x_y'],inplace=True)

# %%
## Add values into state by major corresponding values group by zip, new field is state_x
a = newcard[newcard['Merch zip_x_x'].notna()] 
b = a[a['Merch state'].notna()] ## b is data without NAs in zip_x_x and state
merNum_Des = b.groupby('Merch zip_x_x').agg({'Merch state':lambda x:x.value_counts().index[0]})
newcard = newcard.merge(merNum_Des,right_index=True,left_on='Merch zip_x_x',how='left')
newcard['Merch state_x'].fillna(newcard['Merch state_y'],inplace=True)
newcard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96398 entries, 0 to 96752
# Data columns (total 13 columns):
# Recnum               96398 non-null int64
# Cardnum              96398 non-null int64
# Date                 96398 non-null datetime64[ns]
# Merchnum             93199 non-null object
# Merch description    96398 non-null object
# Merch state_x        96290 non-null object
# Merch zip_x_x        96344 non-null float64
# Transtype            96398 non-null object
# Amount               96398 non-null float64
# Fraud                96398 non-null int64
# Merch zip_y          93185 non-null float64
# Merch zip_x_y        96334 non-null float64
# Merch state_y        96277 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(3), object(5)
# memory usage: 10.3+ MB

# %%
newcard[newcard['Merch state_x'].isna()].head()
# Out:
#       Recnum     Cardnum       Date      Merchnum          Merch description  \
# 3258    3259  5142153880 2010-01-14  582582822587  DIGITAL TECHNOLOGY CONTRA
# 3262    3263  5142154098 2010-01-14  582582822587  DIGITAL TECHNOLOGY CONTRA
# 3540    3541  5142154098 2010-01-17  582582822587  DIGITAL TECHNOLOGY CONTRA
# 3642    3643  5142153880 2010-01-17  582582822587  DIGITAL TECHNOLOGY CONTRA
# 4969    4970  5142194136 2010-01-24  597597721468  CRISTALIA ACQUISITION COR
#
#      Merch state_x  Merch zip_x_x Transtype  Amount  Fraud  Merch zip_y  \
# 3258           NaN          926.0         P  2340.0      0          NaN
# 3262           NaN          926.0         P  2387.0      0          NaN
# 3540           NaN          926.0         P  2300.0      0          NaN
# 3642           NaN          926.0         P  2500.0      0          NaN
# 4969           NaN          929.0         P    83.0      0          NaN
#
#       Merch zip_x_y Merch state_y
# 3258        20746.0           NaN
# 3262        20639.0           NaN
# 3540        20639.0           NaN
# 3642        20746.0           NaN
# 4969        90640.0           NaN

# %%
## We searched the missing value in Zip on Google and find their corresponding State.
dict = {"907.0":"PR", "922.0":"PR", "920.0":"PR", "801.0":"USVI","31040.0":"GA", "41160.0":"KY", "934.0": "PR",
"902.0": "PR", "738.0": "PR", "90805.0": "CA", "76302.0": "TX", "914.0": "PR", "95461.0": "CA", "50823.0": "Other", 
'926.0': "PR", '929.0':"PR", '1400.0':"Other", '65132.0':"Other", '86899.0':"Other", '23080.0':"Other",
'60528.0':"Other", "48700.0": "CA", "680.0": "PR", "681.0": "PR", "623.0": "PR", "726.0": "PR", "936.0": "PR",
"791.0": "PR", "12108.0": "Other", "nan":'Other'}

# %%
## We used the previous dictionary to fill in missing fields in state.
ab = newcard[newcard['Merch state_x'].isna()]
ab['Merch zip_x_x']=ab['Merch zip_x_x'].astype('str')
for i in range(len(ab['Merch zip_x_x'])):
    ab['Merch state_x'].iloc[i]=dict[ab['Merch zip_x_x'].iloc[i]]

# %%
## We replace the values in newcard dataset with filled data
ac = newcard[newcard['Merch state_x'].notna()][['Merch state_x']]
ad = pd.concat([ab[['Merch state_x']],ac])
newcard['Merch state_x'] = ad

# %%
## No NAs in field state now
newcard[newcard['Merch state_x'].isna()]
# Out:
# Empty DataFrame
# Columns: [Recnum, Cardnum, Date, Merchnum, Merch description, Merch state_x, Merch zip_x_x, Transtype, Amount, Fraud, Merch zip_y, Merch zip_x_y, Merch state_y]
# Index: []

# %%
newcard['Merch zip_x_x'].fillna(0,inplace=True)

# %%
# Select the useful columns and change the column name
fdata = newcard[["Recnum","Cardnum","Date","Merch description","Merch state_x","Merch zip_x_x","Transtype","Amount","Fraud"]]
fdata.columns = ["Recnum","Cardnum","Date","Merch description","Merch state","Merch zip","Transtype","Amount","Fraud"]

# %%
fdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96398 entries, 0 to 96752
# Data columns (total 9 columns):
# Recnum               96398 non-null int64
# Cardnum              96398 non-null int64
# Date                 96398 non-null datetime64[ns]
# Merch description    96398 non-null object
# Merch state          96398 non-null object
# Merch zip            96398 non-null float64
# Transtype            96398 non-null object
# Amount               96398 non-null float64
# Fraud                96398 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 7.4+ MB

# %% [markdown]
# # Variable Creation

# %% [markdown]
# ## Amount Variable

# %%
# %%time
fdata['Date']=pd.to_datetime(fdata['Date'])
tot=pd.DataFrame({'Date':[],'Amount':[], 'Cardnum':[]})
for cardnum in fdata['Cardnum'].unique():
    c=fdata[fdata['Cardnum']==cardnum]
    f=c.groupby('Date')['Amount'].sum()
    f1=f.rolling('7d').sum()
    f1=f1/7
    f1=pd.DataFrame(f1)
    f1.reset_index(inplace=True)
    f1['Cardnum'] = [cardnum]* len(f1)
    tot=pd.concat([tot,f1])
# Out:
# CPU times: user 17.4 s, sys: 109 ms, total: 17.5 s
# Wall time: 17.5 s

# %%
md = pd.DataFrame(fdata['Merch description'].unique(),columns=['md'])
md.reset_index(inplace=True)

# %%
fdata=fdata.merge(md,right_on='md',left_on='Merch description',how='left')
fdata.head()
# Out:
#    Recnum     Cardnum       Date        Merch description Merch state  \
# 0       1  5142190439 2010-01-01   FEDEX SHP 12/23/09 AB#          TN
# 1       2  5142183973 2010-01-01  SERVICE MERCHANDISE #81          MA
# 2       3  5142131721 2010-01-01        OFFICE DEPOT #191          MD
# 3       4  5142148452 2010-01-01   FEDEX SHP 12/28/09 AB#          TN
# 4       5  5142190439 2010-01-01   FEDEX SHP 12/23/09 AB#          TN
#
#    Merch zip Transtype  Amount  Fraud  index                       md
# 0    38118.0         P    3.62      0      0   FEDEX SHP 12/23/09 AB#
# 1     1803.0         P   31.42      0      1  SERVICE MERCHANDISE #81
# 2    20706.0         P  178.49      0      2        OFFICE DEPOT #191
# 3    38118.0         P    3.62      0      3   FEDEX SHP 12/28/09 AB#
# 4    38118.0         P    3.62      0      0   FEDEX SHP 12/23/09 AB#

# %%
# %%time
desc='FEDEX SHP 12/23/09 AB#'

c=fdata1.ix[desc]
c.reset_index(inplace=True)
c=c[['Recnum','Merch description','Date']]
diff = []
for i,val in enumerate(c['Date']):
    if i == 0:
        diff.append(0)
    else:
        diff.append((c.Date.iloc[i] - c.Date.iloc[i-1]).days)
c['Diff']=diff
c
# Out:
# CPU times: user 42.9 ms, sys: 2.06 ms, total: 45 ms
# Wall time: 43.6 ms

# %% [markdown]
# ## Day since Variables

# %%
## by Card
dsc=pd.DataFrame({'Recnum':[],'Cardnum':[],'Date':[],'Diff':[]})
f1data=fdata[['Recnum','Cardnum','Date']]
for cardnum in f1data['Cardnum'].unique():
    c=f1data[f1data['Cardnum']==cardnum]
    c.reset_index(inplace=True)
    diff = []
    for i,val in enumerate(c['Date']):
        if i == 0:
            diff.append(365)
        else:
            diff.append((c.Date.iloc[i] - c.Date.iloc[i-1]).days)
    c['Diff']=diff
    dsc=pd.concat([dsc,c])
dsc['Recnum'] = dsc['Recnum'].astype('int')
dsc = dsc[['Cardnum', 'Date', 'Diff', 'Recnum']]

# %%
dsc=dsc[['Diff', 'Recnum']]
dsc.columns=['dscard','Recnum']
dsc
# Out:
#     dscard  Recnum
# 0    365.0       1
# 1      0.0       5
# 2      0.0      10
# 3      0.0      12
# 4      0.0      21
# 5      0.0      22
# 6      0.0      23
# 7      0.0      28
# 8      0.0      34
# 9      0.0      40
# 10     0.0      48
# 11     2.0     127
# 12     1.0     388
# 13     0.0     422
# 14     1.0     730
# 15     1.0     857
# 16     7.0    2810
# 17     1.0    3016
# 18     3.0    3644
# 19     2.0    3981
# 20     1.0    4207
# 21     0.0    4211
# 22     0.0    4223
# 23     0.0    4227
# 24     0.0    4270
# 25     0.0    4273
# 26     0.0    4292
# 27     0.0    4297
# 28     0.0    4321
# 29     0.0    4338
# ..     ...     ...
# 0    365.0   85493
# 0    365.0   86037
# 0    365.0   86071
# 1     13.0   88549
# 0    365.0   86218
# 0    365.0   86324
# 1      7.0   87804
# 0    365.0   86589
# 0    365.0   87088
# 0    365.0   87150
# 0    365.0   87650
# 1      0.0   87691
# 2      1.0   88059
# 0    365.0   87773
# 0    365.0   88332
# 0    365.0   88348
# 1      3.0   88624
# 2      1.0   88819
# 3      0.0   89042
# 0    365.0   88738
# 0    365.0   88802
# 0    365.0   89223
# 0    365.0   89963
# 1      8.0   92023
# 0    365.0   90007
# 1     13.0   93076
# 0    365.0   91281
# 0    365.0   91546
# 0    365.0   94391
# 0    365.0   95582
#
# [96398 rows x 2 columns]

# %%
## By Merch
fdata.sort_values(['Merch description','Date'], inplace = True)
diff = []
f1 = fdata.reset_index()
for i in range(96398):
    if i == 0:
        diff.append(365)
    else:
        diff.append(max(0,(f1.Date.iloc[i] - f1.Date.iloc[i-1]).days))
f1['Diff']=diff
f2=f1.groupby('Merch description').first()
for rec in f2['Recnum']:
    f1['Diff'][f1['Recnum']==rec]=365

# %%
f1=f1[['Diff', 'Recnum']]
f1.columns=['dsmerch','Recnum']

# %%
## by Merchant & card
fdata.sort_values(['Merch description','Cardnum','Date'], inplace = True)
diff = []
f11 = fdata.reset_index()
for i in range(96398):
    if i == 0:
        diff.append(365)
    else:
        diff.append(max(0,(f11.Date.iloc[i] - f11.Date.iloc[i-1]).days))
f11['Diff']=diff
f12=f11.groupby(['Merch description','Cardnum']).first()
for rec in f12['Recnum']:
    f11['Diff'][f11['Recnum']==rec]=365

# %%
f11=f11[['Diff', 'Recnum']]
f11.columns=['dsmerchcard','Recnum']

# %%
## by zip & card
fdata.sort_values(['Merch zip','Cardnum','Date'], inplace = True)
diff = []
f21 = fdata.reset_index()
for i in range(96398):
    if i == 0:
        diff.append(365)
    else:
        diff.append(max(0,(f21.Date.iloc[i] - f21.Date.iloc[i-1]).days))
f21['Diff']=diff
f22=f21.groupby(['Merch zip','Cardnum']).first()
for rec in f22['Recnum']:
    f21['Diff'][f21['Recnum']==rec]=365

# %%
f21=f21[['Diff', 'Recnum']]
f21.columns=['dszipcard','Recnum']

# %%
## by state & card
fdata.sort_values(['Merch state','Cardnum','Date'], inplace = True)
diff = []
f31 = fdata.reset_index()
for i in range(96398):
    if i == 0:
        diff.append(365)
    else:
        diff.append(max(0,(f31.Date.iloc[i] - f31.Date.iloc[i-1]).days))
f31['Diff']=diff
f32=f31.groupby(['Merch state','Cardnum']).first()
for rec in f32['Recnum']:
    f31['Diff'][f31['Recnum']==rec]=365

# %%
f31=f31[['Diff', 'Recnum']]
f31.columns=['dsstatecard','Recnum']

# %%
fdata1=fdata.merge(dsc,right_on='Recnum',left_on='Recnum',how='left')
fdata2=fdata1.merge(f1,right_on='Recnum',left_on='Recnum',how='left')
fdata3=fdata2.merge(f11,right_on='Recnum',left_on='Recnum',how='left')
fdata4=fdata3.merge(f21,right_on='Recnum',left_on='Recnum',how='left')
fdata5=fdata4.merge(f31,right_on='Recnum',left_on='Recnum',how='left')

# %%
fdata5
# Out:
#        Recnum     Cardnum       Date          Merch description Merch state  \
# 0       89917  5142111372 2010-11-30      COMMUNICATION SYSTEMS          AB
# 1       44964  5142117641 2010-06-15     AGRICULTURE FOOD & RUR          AB
# 2       80133  5142251947 2010-10-06     TROUT UNLIMITED CANADA          AB
# 3       83156  5142254784 2010-10-25  ENVIRONMENTAL SERVICES AS          AB
# 4       50777  5142291592 2010-07-06      SEQUITER SOFTWARE INC          AB
# 5         467  5142111572 2010-01-04              GREENSTAR INC          AK
# 6        1126  5142111572 2010-01-07      ARCTIC OFFICE MACHINE          AK
# 7        1932  5142111572 2010-01-11     ALASKA PACIFIC UNIVERS          AK
# 8        2816  5142111572 2010-01-13              UAA BOOKSTORE          AK
# 9        3808  5142111572 2010-01-18            SUNSET SERVICES          AK
# 10       4703  5142111572 2010-01-21       ANCHORAGE DAILY NEWS          AK
# 11       4942  5142111572 2010-01-23       HAWTHORN SUITES, LTD          AK
# 12       6847  5142111572 2010-02-01                  LOGISTICS          AK
# 13       6873  5142111572 2010-02-01                  LOGISTICS          AK
# 14       6928  5142111572 2010-02-01                  LOGISTICS          AK
# 15       6951  5142111572 2010-02-01                  LOGISTICS          AK
# 16       6955  5142111572 2010-02-01                  LOGISTICS          AK
# 17       6969  5142111572 2010-02-01                  LOGISTICS          AK
# 18       6972  5142111572 2010-02-01                  LOGISTICS          AK
# 19       6981  5142111572 2010-02-01                  LOGISTICS          AK
# 20       6998  5142111572 2010-02-01                  LOGISTICS          AK
# 21       7115  5142111572 2010-02-01                  LOGISTICS          AK
# 22       7127  5142111572 2010-02-01                  LOGISTICS          AK
# 23       7139  5142111572 2010-02-01                  LOGISTICS          AK
# 24       7174  5142111572 2010-02-01                  LOGISTICS          AK
# 25      14501  5142111572 2010-02-28       HAWTHORN SUITES, LTD          AK
# 26      16299  5142111572 2010-03-07        INTERNET ALASKA  IN          AK
# 27      16850  5142111572 2010-03-08            AK MINERS ASSOC          AK
# 28      16993  5142111572 2010-03-09        INTERNET ALASKA  IN          AK
# 29      17081  5142111572 2010-03-09          ALASKA CLEAN SEAS          AK
# ...       ...         ...        ...                        ...         ...
# 18       99501.0         P    75.00      0     0.0        0            0
# 19       99501.0         P    75.00      0     0.0        0            0
# 20       99501.0         P    75.00      0     0.0        0            0
# 21       99501.0         P    75.00      0     0.0        0            0
# 22       99501.0         P    75.00      0     0.0        0            0
# 23       99501.0         P    75.00      0     0.0        0            0
# 24       99501.0         P    75.00      0     0.0        0            0
# 25       99501.0         P   720.00      0    27.0       36           36
# 26       99508.0         P   780.00      0     7.0      365          365
# 27       99709.0         P   130.00      0     1.0      365          365
# 28       99508.0         P   780.00      0     1.0        2            2
# 29       99734.0         P   600.00      0     0.0      365          365
# ...          ...       ...      ...    ...     ...      ...          ...
# 96368    25443.0         P  1545.00      0     0.0       30          365
# 96369    25443.0         P  5301.00      0     3.0       40          365
# 96370    25443.0         P   500.00      0     0.0        0          365
# 96371    82070.0         P   209.30      0     2.0       63          365
# 96372    82070.0         P   162.00      0     7.0        1          365
# 96373    82070.0         P  2122.29      0   365.0      365          365
# 96374    82070.0         P  2484.15      0    41.0      134          134
# 96375    82070.0         P  1779.60      0     6.0       34          174
# 96376    82070.0         P   645.50      0    76.0       63          365
# 96377    82901.0         P    21.99      0     1.0      365          365
# 96378    82070.0         P   151.00      0     1.0      140          365
# 96379    82801.0         P  1237.00      0     5.0      365          365
# 96380    82801.0         P   768.00      0     1.0       57           57
# 96381    82070.0         P   233.89      0     8.0       14          365
# 96382    83001.0         P    77.40      0     0.0      365          365
# 96383    82609.0         P    52.18      0     5.0        4           14
# 96384    82609.0         P    17.72      0     2.0        0            2
# 96385    82609.0         P    71.70      0     0.0        3           54
# 96386    82007.0         P   108.70      0   365.0      365          365
# 96387    82801.0         P   335.00      0     4.0       71          365
# 96388    82070.0         P   685.00      0     5.0      365          365
# 96389    82070.0         P    85.00      0     0.0       13           13
# 96390    82602.0         P   329.00      0     1.0      365          365
# 96391    82520.0         P    21.75      0     4.0      365          365
# 96392    82431.0         P   138.75      0     6.0      365          365
# 96393    82601.0         P   503.20      0     1.0      365          365
# 96394    82071.0         P   125.00      0     7.0      365          365
# 96395    82073.0         P   262.62      0     2.0      365          365
# 96396    82070.0         P   281.75      0     1.0       15          365
# 96397    82070.0         P   142.00      0     0.0       78          365
#
#        dszipcard  dsstatecard
# 0            212          365
# 1             10          365
# 2             36          365
# 3             21          365
# 4             14          365
# 5            365          365
# 6            365            3
# 7            365            4
# 8            365            2
# 9            365            5
# 10            10            3
# 11           365            2
# 12            28            9
# 13             0            0
# 14             0            0
# 15             0            0
# 16             0            0
# 17             0            0
# 18             0            0
# 19             0            0
# 20             0            0
# 21             0            0
# 22             0            0
# 23             0            0
# 24             0            0
# 25            27           27
# 26            45            7
# 27           365            1
# 28             2            1
# 29           365            0
# ...          ...          ...
# 96368        365          365
# 96369        365          365
# 96370        365          365
# 96371        365          365
# 96372        365          365
# 96373        365          365
# 96374        134          134
# 96375        174          174
# 96376        365          365
# 96377        365          365
# 96378        365          365
# 96379        365          365
# 96380         57           57
# 96381        365          365
# 96382        365          365
# 96383        365          365
# 96384          2            2
# 96385        192          192
# 96386        365          365
# 96387        365          365
# 96388        365          365
# 96389         13           13
# 96390        365          365
# 96391        365           35
# 96392        365          365
# 96393        365          365
# 96394        365          365
# 96395        365          365
# 96396        365          365
# 96397        365          365
#
# [96398 rows x 14 columns]

# %%
ffdata = fdata5.sort_values('Recnum')

# %%
ffdata = ffdata[["Recnum","Cardnum","Date","Merch description","Merch state","Merch zip","Transtype","Amount","Fraud",'dscard','dsmerch','dsmerchcard','dszipcard','dsstatecard']]
ffdata
# Out:
#        Recnum     Cardnum       Date         Merch description Merch state  \
# 75187       1  5142190439 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 31149       2  5142183973 2010-01-01   SERVICE MERCHANDISE #81          MA
# 33302       3  5142131721 2010-01-01         OFFICE DEPOT #191          MD
# 71917       4  5142148452 2010-01-01    FEDEX SHP 12/28/09 AB#          TN
# 75188       5  5142190439 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 73780       6  5142149874 2010-01-01    FEDEX SHP 12/22/09 AB#          TN
# 74932       7  5142189277 2010-01-01    FEDEX SHP 12/28/09 AB#          TN
# 56335       8  5142191182 2010-01-01     MIAMI COMPUTER SUPPLY          OH
# 20150       9  5142258629 2010-01-01            FISHER SCI ATL          GA
# 75189      10  5142190439 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 76701      11  5142283088 2010-01-01    FEDEX SHP 12/22/09 AB#          TN
# 75190      12  5142190439 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 71370      13  5142146134 2010-01-01    FEDEX SHP 12/21/09 AB#          TN
# 21820      14  5142124791 2010-01-01        CDW*GOVERNMENT INC          IL
# 22373      15  5142151402 2010-01-01        CDW*GOVERNMENT INC          IL
# 71915      16  5142148452 2010-01-01    FEDEX SHP 12/22/09 AB#          TN
# 71918      17  5142148452 2010-01-01    FEDEX SHP 12/28/09 AB#          TN
# 67640      18  5142125684 2010-01-01    FEDEX SHP 12/22/09 AB#          TN
# 70179      19  5142139349 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 80330      20  5142190596 2010-01-01            FISHER SCI HUS          TX
# 75185      21  5142190439 2010-01-01    FEDEX SHP 12/22/09 AB#          TN
# 75191      22  5142190439 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 75186      23  5142190439 2010-01-01    FEDEX SHP 12/22/09 AB#          TN
# 93276      24  5142217905 2010-01-01    AMAZON.COM  *SUPERSTRE          WA
# 74107      25  5142152067 2010-01-01    FEDEX SHP 12/21/09 AB#          TN
# 71408      26  5142146833 2010-01-01    FEDEX SHP 12/21/09 AB#          TN
# 23924      27  5142183817 2010-01-01        CDW*GOVERNMENT INC          IL
# 75192      28  5142190439 2010-01-01    FEDEX SHP 12/23/09 AB#          TN
# 27280      29  5142270480 2010-01-01        CDW*GOVERNMENT INC          IL
# 71919      30  5142148452 2010-01-01    FEDEX SHP 12/28/09 AB#          TN
# ...       ...         ...        ...                       ...         ...
# 1682    96724  5142127070 2010-12-31    CC *PC MALL GOVERNMENT          CA
# 41493   96725  5142178899 2010-12-31    ELECTRONIC SUPPLY CO I          MO
# 94489   96726  5142253938 2010-12-31    TIMES PI SUBSCRIPTIONS          WA
# 20680   96727  5142276099 2010-12-31            FISHER SCI ATL          GA
# 75185    38118.0         P     3.62      0     0.0        0          365
# 75191    38118.0         P     3.62      0     0.0        0            0
# 75186    38118.0         P     3.67      0     0.0        0            0
# 93276    98101.0         P    68.90      0   365.0      365          365
# 74107    38118.0         P     3.67      0   365.0        0          365
# 71408    38118.0         P     3.62      0   365.0        0          365
# 23924    60061.0         P   360.00      0   365.0        0          365
# 75192    38118.0         P     3.62      0     0.0        0            0
# 27280    60061.0         P   427.00      0   365.0        0          365
# 71919    38118.0         P     3.80      0     0.0        0            0
# ...          ...       ...      ...    ...     ...      ...          ...
# 1682     90503.0         P   179.99      0     1.0        8            8
# 41493    64111.0         P   144.80      0     3.0        9           15
# 94489    98109.0         P   106.60      0     0.0        0            0
# 20680    30091.0         P   208.36      0     0.0        0           24
# 74655    38118.0         P     4.43      0     4.0      104          365
# 58156    45150.0         P  2487.98      0     0.0        0            0
# 18664    30319.0         P   274.54      0    15.0        2          331
# 53401    10010.0         P   340.79      0     1.0        1          365
# 92987    98055.0         P    47.05      0     3.0       14          365
# 27451    60143.0         P   441.53      0     0.0        0            0
# 89782    23235.0         P   114.93      0    38.0      365          365
# 15067    30303.0         P    33.17      0    16.0      317          317
# 25737    60061.0         P  1888.00      0     0.0        0            0
# 33441    20763.0         P   161.50      0     1.0        1            1
# 58279    45246.0         P   114.91      0    91.0      167          365
# 66774    57049.0         P  1610.40      0     8.0        4          318
# 10486     6514.0         P   165.00      0     2.0       13           55
# 38068     4032.0         P    44.95      0    23.0        3          365
# 24584    60061.0         P    13.59      0     1.0        0           73
# 20478    30091.0         P    62.14      0     9.0        0            9
# 24417    60061.0         P  2231.08      0     1.0        2          149
# 59575    97330.0         P   243.15      1     0.0        9            9
# 19517    30091.0         P    32.04      0     0.0        0            2
# 44462    27560.0         P   147.35      0     2.0        9          365
# 25738    60061.0         P   425.00      0     0.0        0            0
# 30205    41042.0         P    84.79      0    37.0      365          365
# 57674    45248.0         P   118.75      0     0.0        9           11
# 57914    45150.0         P   363.56      0     1.0        4          365
# 6271     92656.0         P  2202.03      0     9.0        1           26
# 51644     7606.0         P   554.64      0     2.0        1            2
#
#        dszipcard  dsstatecard
# 75187          0            0
# 31149        365          365
# 33302        365          365
# 71917          0            0
# 75188          0            0
# 73780        365          365
# 74932        365          365
# 56335        365          365
# 20150        365          365
# 75189          0            0
# 76701        365          365
# 75190          0            0
# 71370        365          365
# 21820        365          365
# 22373        365          365
# 71915        365          365
# 71918          0            0
# 67640        365          365
# 70179        365          365
# 80330        365          365
# 75185        365          365
# 75191          0            0
# 75186          0            0
# 93276        365          365
# 74107        365          365
# 71408        365          365
# 23924        365          365
# 75192          0            0
# 27280        365          365
# 71919          0            0
# ...          ...          ...
# 1682           8            8
# 41493         15           14
# 94489          0            0
# 20680         24           24
# 74655          4            4
# 58156          0            0
# 18664        331          331
# 53401          1            1
# 92987        365           79
# 27451          0            0
# 89782        365          365
# 15067         46          139
# 25737          0            0
# 33441          1            1
# 58279        327          101
# 66774          8            8
# 10486         55           55
# 38068        365          365
# 24584         46           27
# 20478          9            9
# 24417        149           18
# 59575          1            1
# 19517          2            2
# 44462        324           39
# 25738          0            0
# 30205         37           37
# 57674         11            2
# 57914        365            1
# 6271          26           26
# 51644          2            2
#
# [96398 rows x 14 columns]

# %%
ffdata.to_csv('ffdata.csv')

# %%
from scipy.stats import ks_2samp

# %%
mydata=ffdata[['Fraud', 'dscard', 'dsmerch','dsmerchcard', 'dszipcard', 'dsstatecard']]
goods=mydata[mydata['Fraud']==0]
bads=mydata[mydata['Fraud']==1]

# %%
KS={'Fraud':[0], 'dscard':[0], 'dsmerch':[0], 'dsmerchcard':[0], 'dszipcard':[0],'dsstatecard':[0]}
KS=pd.DataFrame.from_dict(KS, orient='index')
KS.reset_index(inplace=True)

# %%
KS['ks']=[0,0,0,0,0,0]

# %%
i=0
for column in list(mydata.columns):
    KS['ks'][i] = ks_2samp(goods[column],bads[column])[0]
    i = i+1

# %%
KS
# Out:
#          index  0  ks
# 0        Fraud  0   1
# 1       dscard  0   0
# 2      dsmerch  0   0
# 3  dsmerchcard  0   0
# 4    dszipcard  0   0
# 5  dsstatecard  0   0

# %%
mydata.sort_values('dscard').reset_index().index
# Out:
# RangeIndex(start=0, stop=96398, step=1)

# %%
mydata['dscardscore']=mydata.sort_values('dscard').reset_index().index
mydata['dsmerchscore']=mydata.sort_values('dsmerch').reset_index().index
mydata['dsmerchcardscore']=mydata.sort_values('dsmerchcard').reset_index().index
mydata['dsstatecardscore']=mydata.sort_values('dsstatecard').reset_index().index
mydata['dszipcardscore']=mydata.sort_values('dszipcard').reset_index().index

# %%
mydata.sort_values('dszipcard',ascending=False).iloc[:2892,]['Fraud'].sum()
# Out:
# 58

# %%
mydata['Fraud'].sum()
# Out:
# 1059

# %%
mydata1
# Out:
#        Unnamed: 0     V1  Recnum     Cardnum        Date  \
# 0               1      0       1  5142190439  2010-01-01
# 1               2      1       2  5142183973  2010-01-01
# 2               3      2       3  5142131721  2010-01-01
# 3               4      3       4  5142148452  2010-01-01
# 4               5      4       5  5142190439  2010-01-01
# 5               6      5       6  5142149874  2010-01-01
# 6               7      6       7  5142189277  2010-01-01
# 7               8      7       8  5142191182  2010-01-01
# 8               9      8       9  5142258629  2010-01-01
# 9              10      9      10  5142190439  2010-01-01
# 10             11     10      11  5142283088  2010-01-01
# 11             12     11      12  5142190439  2010-01-01
# 12             13     12      13  5142146134  2010-01-01
# 13             14     13      14  5142124791  2010-01-01
# 14             15     14      15  5142151402  2010-01-01
# 15             16     15      16  5142148452  2010-01-01
# 16             17     16      17  5142148452  2010-01-01
# 17             18     17      18  5142125684  2010-01-01
# 18             19     18      19  5142139349  2010-01-01
# 19             20     19      20  5142190596  2010-01-01
# 20             21     20      21  5142190439  2010-01-01
# 21             22     21      22  5142190439  2010-01-01
# 22             23     22      23  5142190439  2010-01-01
# 23             24     23      24  5142217905  2010-01-01
# 24             25     24      25  5142152067  2010-01-01
# 17       FEDEX SHP 12/22/09 AB#          TN      38118         P     3.67
# 18       FEDEX SHP 12/23/09 AB#          TN      38118         P     3.67
# 19               FISHER SCI HUS          TX      77251         P   218.57
# 20       FEDEX SHP 12/22/09 AB#          TN      38118         P     3.62
# 21       FEDEX SHP 12/23/09 AB#          TN      38118         P     3.62
# 22       FEDEX SHP 12/22/09 AB#          TN      38118         P     3.67
# 23       AMAZON.COM  *SUPERSTRE          WA      98101         P    68.90
# 24       FEDEX SHP 12/21/09 AB#          TN      38118         P     3.67
# 25       FEDEX SHP 12/21/09 AB#          TN      38118         P     3.62
# 26           CDW*GOVERNMENT INC          IL      60061         P   360.00
# 27       FEDEX SHP 12/23/09 AB#          TN      38118         P     3.62
# 28           CDW*GOVERNMENT INC          IL      60061         P   427.00
# 29       FEDEX SHP 12/28/09 AB#          TN      38118         P     3.80
# ...                         ...         ...        ...       ...      ...
# 96368    CC *PC MALL GOVERNMENT          CA      90503         P   179.99
# 96369    ELECTRONIC SUPPLY CO I          MO      64111         P   144.80
# 96370    TIMES PI SUBSCRIPTIONS          WA      98109         P   106.60
# 96371            FISHER SCI ATL          GA      30091         P   208.36
# 96372    FEDEX SHP 04/03/10 AB#          TN      38118         P     4.43
# 96373             TECH PAC, INC          OH      45150         P  2487.98
# 96374               AGILENT SAP          GA      30319         P   274.54
# 96375   RETAIL DEBIT ADJUSTMENT          NY      10010         P   340.79
# 96376      MZI*PC ZONE MAC ZONE          WA      98055         P    47.05
# 96377            FISHER SCI CHI          IL      60143         P   441.53
# 96378    BEST BUY      00004226          VA      23235         P   114.93
# 96379           OKEECHOBEE NEWS          FL      30303         P    33.17
# 96380        CDW*GOVERNMENT INC          IL      60061         P  1888.00
# 96381        OFFICE DEPOT #1082          MD      20763         P   161.50
# 96382      CINCINNATI CONTAINER          OH      45246         P   114.91
# 96383   GATEWAY BUSINESS DIRECT          SD      57049         P  1610.40
# 96384    ABSOLUTE STANDARDS INC          CT       6514         P   165.00
# 96385    DEL*DELORME PUBLISHING          ME       4032         P    44.95
# 96386        CDW*GOVERNMENT INC          IL      60061         P    13.59
# 96387            FISHER SCI ATL          GA      30091         P    62.14
# 96388        CDW*GOVERNMENT INC          IL      60061         P  2231.08
# 96389  COMPUTER STORE OF CORVLS          OR      97330         P   243.15
# 96390            FISHER SCI ATL          GA      30091         P    32.04
# 96391               STAY ONLINE          NC      27560         P   147.35
# 96392        CDW*GOVERNMENT INC          IL      60061         P   425.00
# 96393    BEST BUY      00001610          KY      41042         P    84.79
# 96394    MARKUS OFFICE SUPPLIES          OH      45248         P   118.75
# 96395             TECH PAC, INC          OH      45150         P   363.56
# 96396                   BUY.COM          CA      92656         P  2202.03
# 96397     STAPLES NATIONAL #471          NJ       7606         P   554.64
#
#             ...         cars_mz14_median  cars_mz14_min  cars_mz14_total  \
# 0           ...                    3.620           3.62             3.62
# 1           ...                   31.420          31.42            31.42
# 2           ...                  178.490         178.49           178.49
# 3           ...                    3.620           3.62             3.62
# 96375         200.00           770.79                3
# 96376          47.05            47.05                1
# 96377          82.59           932.76                5
# 96378         114.93           114.93                1
# 96379          33.17            33.17                1
# 96380         343.61          3942.15                5
# 96381           5.41          2128.02               11
# 96382         114.91           114.91                1
# 96383         275.75          1886.15                2
# 96384         165.00           165.00                1
# 96385          44.95            44.95                1
# 96386          13.59            13.59                1
# 96387          62.14           715.88                2
# 96388        2231.08          2231.08                1
# 96389          22.76         14527.12               40
# 96390          32.04            77.43                2
# 96391         147.35           147.35                1
# 96392         343.61          4367.15                6
# 96393          84.79            84.79                1
# 96394         118.75           718.60                2
# 96395         363.56           363.56                1
# 96396          60.35          2745.63                3
# 96397          76.80          3864.32                4
#
# [96398 rows x 311 columns]

# %%
mydata1.sort_values('cars_mz14_total',ascending=False).iloc[:2892,]['Fraud'].sum()
# Out:
# 630

# %%
import pandas as pd
import numpy as np
mydata = pd.read_csv('var310.csv')
mydata1 = pd.read_csv('ffdata.csv')

# %%
mydata1.head()
# Out:
#    Unnamed: 0  Recnum     Cardnum        Date        Merch description  \
# 0       75187       1  5142190439  2010-01-01   FEDEX SHP 12/23/09 AB#
# 1       31149       2  5142183973  2010-01-01  SERVICE MERCHANDISE #81
# 2       33302       3  5142131721  2010-01-01        OFFICE DEPOT #191
# 3       71917       4  5142148452  2010-01-01   FEDEX SHP 12/28/09 AB#
# 4       75188       5  5142190439  2010-01-01   FEDEX SHP 12/23/09 AB#
#
#   Merch state  Merch zip Transtype  Amount  Fraud  dscard  dsmerch  \
# 0          TN    38118.0         P    3.62      0   365.0        0
# 1          MA     1803.0         P   31.42      0   365.0      365
# 2          MD    20706.0         P  178.49      0   365.0      365
# 3          TN    38118.0         P    3.62      0   365.0      365
# 4          TN    38118.0         P    3.62      0     0.0        0
#
#    dsmerchcard  dszipcard  dsstatecard
# 0          365          0            0
# 1          365        365          365
# 2          365        365          365
# 3          365          0            0
# 4            0          0            0

# %%
flag1 = mydata.merge(mydata1, left_on="Recnum", right_on="Recnum",how='left')

# %%
flag1.columns
# Out:
# Index(['Unnamed: 0_x', 'V1', 'Recnum', 'Cardnum_x', 'Date_x',
#        'Merch description_x', 'Merch state_x', 'Merch zip_x', 'Transtype_x',
#        'Amount_x',
#        ...
#        'Merch state_y', 'Merch zip_y', 'Transtype_y', 'Amount_y', 'Fraud_y',
#        'dscard', 'dsmerch', 'dsmerchcard', 'dszipcard', 'dsstatecard'],
#       dtype='object', length=325)

# %%
flag2 = flag1[flag1['Amount_x']!=max(flag1['Amount_x'])]

# %%
flag2.shape
# Out:
# (96397, 325)

# %%
flag2['Date_x']=pd.to_datetime(flag2['Date_x'])
flag3 = flag2[flag2['Date_x']<= pd.to_datetime('2010-11-01')]
# Out:
# /Users/chenxingyuan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
type(flag3['Date_x'][1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
flag3.to_csv('flag3.csv')

# %%
flag3['random'] = np.random.random(size = len(flag3['V1']))
# Out:
# /Users/chenxingyuan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
goods=flag3[flag3['Fraud_x']==0]
bads=flag3[flag3['Fraud_x']==1]

# %%
from scipy.stats import ks_2samp
KS=[]
i=0
l = list(flag3.columns)
fl = l[10:-15]+l[-6:]
for column in fl:
    KS.append( [ks_2samp(goods[column],bads[column])[0],column])
    i = i+1

# %%
len(KS)
# Out:
# 307

# %%
from operator import itemgetter
KS_flag=pd.DataFrame(sorted(KS, key=itemgetter(0),reverse=True))

# %%
KS_flag1 = KS_flag.reset_index()

# %%
KS_flag1['index']=KS_flag1['index']+1

# %%
l = list(flag3.columns)
fl = l[10:-15]+l[-6:]
fdrdic = {}
for i in fl:
    a = flag3[['Fraud_y',i]]
    fdr=a.sort_values(i,ascending = False)['Fraud_y'].iloc[:2526,].sum()/880
    fdrdic[i] = fdr

# %%
len(fdrdic)
# Out:
# 307

# %%
fdrdic
# Out:
# {'Fraud_x': 1.0,
#  'Actual_avg_card_0': 0.05113636363636364,
#  'Actual_max_card_0': 0.013636363636363636,
#  'Actual_med_card_0': 0.06363636363636363,
#  'Actual_tot_card_0': 0.010227272727272727,
#  'Actual_avg_card_1': 0.04659090909090909,
#  'Actual_max_card_1': 0.013636363636363636,
#  'Actual_med_card_1': 0.045454545454545456,
#  'Actual_tot_card_1': 0.00909090909090909,
#  'Actual_avg_card_3': 0.05568181818181818,
#  'Actual_max_card_3': 0.026136363636363635,
#  'Actual_med_card_3': 0.05454545454545454,
#  'Actual_tot_card_3': 0.005681818181818182,
#  'Actual_avg_card_7': 0.07272727272727272,
#  'Actual_max_card_7': 0.029545454545454545,
#  'Actual_med_card_7': 0.07954545454545454,
#  'Actual_tot_card_7': 0.011363636363636364,
#  'Actual_avg_card_14': 0.07386363636363637,
#  'Actual_max_card_14': 0.03068181818181818,
#  'Actual_med_card_14': 0.07727272727272727,
#  'Actual_tot_card_14': 0.0125,
#  'Actual_avg_card_30': 0.0875,
#  'Actual_max_card_30': 0.03636363636363636,
#  'Actual_med_card_30': 0.1125,
#  'Actual_tot_card_30': 0.01818181818181818,
#  'Actual_avg_md_0': 0.08295454545454546,
#  'Actual_max_md_0': 0.020454545454545454,
#  'Actual_med_md_0': 0.06818181818181818,
#  'Actual_tot_md_0': 0.04090909090909091,
#  'Actual_avg_md_1': 0.08068181818181819,
#  'Actual_max_md_1': 0.038636363636363635,
#  'Actual_med_md_1': 0.07727272727272727,
#  'Actual_tot_md_1': 0.0375,
#  'Actual_avg_md_3': 0.09886363636363636,
#  'Actual_max_md_3': 0.026136363636363635,
#  'Actual_med_md_3': 0.09659090909090909,
#  'Actual_tot_md_3': 0.007954545454545454,
#  'Actual_avg_md_7': 0.12045454545454545,
#  'Actual_max_md_7': 0.015909090909090907,
#  'Actual_med_md_7': 0.14886363636363636,
#  'Actual_tot_md_7': 0.023863636363636365,
#  'Actual_avg_md_14': 0.14545454545454545,
#  'Actual_max_md_14': 0.048863636363636366,
#  'Actual_med_md_14': 0.18977272727272726,
#  'Actual_tot_md_14': 0.014772727272727272,
#  'Actual_avg_md_30': 0.18295454545454545,
#  'Actual_max_md_30': 0.023863636363636365,
#  'Actual_med_md_30': 0.22386363636363638,
#  'Actual_tot_md_30': 0.0125,
#  'Actual_avg_card_md0': 0.09431818181818181,
#  'Actual_max_card_md0': 0.019318181818181818,
#  'Actual_med_card_md0': 0.09772727272727273,
#  'Actual_tot_card_md0': 0.017045454545454544,
#  'Actual_avg_card_ms0': 0.05909090909090909,
#  'Actual_max_card_ms0': 0.0125,
#  'Actual_med_card_ms0': 0.07045454545454545,
#  'Actual_tot_card_ms0': 0.010227272727272727,
#  'Actual_avg_card_mz0': 0.0715909090909091,
#  'Actual_max_card_mz0': 0.013636363636363636,
#  'Actual_med_card_mz0': 0.07954545454545454,
#  'Actual_tot_card_mz0': 0.010227272727272727,
#  'Actual_avg_card_md1': 0.08863636363636364,
#  'Actual_max_card_md1': 0.017045454545454544,
#  'Actual_med_card_md1': 0.09772727272727273,
#  'Actual_tot_card_md1': 0.015909090909090907,
#  'Actual_avg_card_ms1': 0.06363636363636363,
#  'Actual_max_card_ms1': 0.007954545454545454,
#  'Actual_med_card_ms1': 0.07045454545454545,
#  'Actual_tot_card_ms1': 0.006818181818181818,
#  'Actual_avg_card_mz1': 0.07386363636363637,
#  'Actual_max_card_mz1': 0.00909090909090909,
#  'Actual_med_card_mz1': 0.08409090909090909,
#  'Actual_tot_card_mz1': 0.029545454545454545,
#  'Actual_avg_card_md3': 0.08863636363636364,
#  'Actual_max_card_md3': 0.017045454545454544,
#  'Actual_med_card_md3': 0.1,
#  'Actual_tot_card_md3': 0.014772727272727272,
#  'Actual_avg_card_ms3': 0.0659090909090909,
#  'Actual_max_card_ms3': 0.00909090909090909,
#  'Actual_med_card_ms3': 0.075,
#  'Actual_tot_card_ms3': 0.02727272727272727,
#  'Actual_avg_card_mz3': 0.0715909090909091,
#  'Actual_max_card_mz3': 0.00909090909090909,
#  'Actual_med_card_mz3': 0.075,
#  'Actual_tot_card_mz3': 0.013636363636363636,
#  'Actual_avg_card_md7': 0.07954545454545454,
#  'Actual_max_card_md7': 0.019318181818181818,
#  'Actual_med_card_md7': 0.10454545454545454,
#  'Actual_tot_card_md7': 0.010227272727272727,
#  'Actual_avg_card_ms7': 0.0659090909090909,
#  'Actual_max_card_ms7': 0.025,
#  'Actual_med_card_ms7': 0.0625,
#  'Actual_tot_card_ms7': 0.022727272727272728,
#  'Actual_avg_card_mz7': 0.07272727272727272,
#  'Actual_max_card_mz7': 0.011363636363636364,
#  'Actual_med_card_mz7': 0.09431818181818181,
#  'Actual_tot_card_mz7': 0.0375,
#  'Actual_avg_card_md14': 0.07727272727272727,
#  'Actual_max_card_md14': 0.020454545454545454,
#  'Actual_med_card_md14': 0.1,
#  'Actual_tot_card_md14': 0.010227272727272727,
#  'Actual_avg_card_ms14': 0.06704545454545455,
#  'Actual_max_card_ms14': 0.007954545454545454,
#  'Actual_med_card_ms14': 0.05909090909090909,
#  'Actual_tot_card_ms14': 0.019318181818181818,
#  'Actual_avg_card_mz14': 0.06931818181818182,
#  'Actual_max_card_mz14': 0.013636363636363636,
#  'Actual_med_card_mz14': 0.0715909090909091,
#  'Actual_tot_card_mz14': 0.007954545454545454,
#  'Actual_avg_card_md30': 0.07386363636363637,
#  'Actual_max_card_md30': 0.015909090909090907,
#  'Actual_med_card_md30': 0.09431818181818181,
#  'Actual_tot_card_md30': 0.031818181818181815,
#  'Actual_avg_card_ms30': 0.06818181818181818,
#  'Actual_max_card_ms30': 0.017045454545454544,
#  'Actual_med_card_ms30': 0.05795454545454545,
#  'Actual_tot_card_ms30': 0.00909090909090909,
#  'Actual_avg_card_mz30': 0.06477272727272727,
#  'Actual_max_card_mz30': 0.0375,
#  'Actual_med_card_mz30': 0.05568181818181818,
#  'Actual_tot_card_mz30': 0.017045454545454544,
#  'card_0_mean': 0.32386363636363635,
#  'card_0_max': 0.4193181818181818,
#  'card_0_median': 0.30454545454545456,
#  'card_0_min': 0.20909090909090908,
#  'card_0_total': 0.5477272727272727,
#  'card_0_count': 0.1693181818181818,
#  'card_1_mean': 0.35113636363636364,
#  'card_1_max': 0.425,
#  'card_1_median': 0.32840909090909093,
#  'card_1_min': 0.1590909090909091,
#  'card_1_total': 0.5409090909090909,
#  'card_1_count': 0.2636363636363636,
#  'card_3_mean': 0.3568181818181818,
#  'card_3_max': 0.45,
#  'card_3_median': 0.32386363636363635,
#  'card_3_min': 0.09886363636363636,
#  'card_3_total': 0.5488636363636363,
#  'card_3_count': 0.19204545454545455,
#  'card_7_mean': 0.39886363636363636,
#  'card_7_max': 0.48295454545454547,
#  'card_7_median': 0.30454545454545456,
#  'card_7_min': 0.08977272727272727,
#  'card_7_total': 0.5159090909090909,
#  'card_7_count': 0.08409090909090909,
#  'card_14_mean': 0.4,
#  'card_14_max': 0.509090909090909,
#  'card_14_median': 0.32386363636363635,
#  'card_14_min': 0.11818181818181818,
#  'card_14_total': 0.4738636363636364,
#  'card_14_count': 0.02159090909090909,
#  'card_30_mean': 0.3784090909090909,
#  'card_30_max': 0.4,
#  'card_30_median': 0.28863636363636364,
#  'card_30_min': 0.10227272727272728,
#  'card_30_total': 0.4022727272727273,
#  'card_30_count': 0.003409090909090909,
#  'md_0_mean': 0.30568181818181817,
#  'md_0_max': 0.43863636363636366,
#  'md_0_median': 0.28295454545454546,
#  'md_0_min': 0.22386363636363638,
#  'md_0_total': 0.55,
#  'md_0_count': 0.019318181818181818,
#  'md_1_mean': 0.29772727272727273,
#  'md_1_max': 0.43522727272727274,
#  'md_1_median': 0.27954545454545454,
#  'md_1_min': 0.1943181818181818,
#  'md_1_total': 0.4681818181818182,
#  'md_1_count': 0.045454545454545456,
#  'md_3_mean': 0.2761363636363636,
#  'md_3_max': 0.4340909090909091,
#  'md_3_median': 0.27386363636363636,
#  'md_3_min': 0.13977272727272727,
#  'md_3_total': 0.41363636363636364,
#  'md_3_count': 0.0125,
#  'md_7_mean': 0.27386363636363636,
#  'md_7_max': 0.45681818181818185,
#  'md_7_median': 0.24886363636363637,
#  'md_7_min': 0.10681818181818181,
#  'md_7_total': 0.3465909090909091,
#  'md_7_count': 0.0022727272727272726,
#  'md_14_mean': 0.26704545454545453,
#  'md_14_max': 0.36363636363636365,
#  'md_14_median': 0.21818181818181817,
#  'md_14_min': 0.09204545454545454,
#  'md_14_total': 0.2431818181818182,
#  'md_14_count': 0.011363636363636364,
#  'md_30_mean': 0.24545454545454545,
#  'md_30_max': 0.22272727272727272,
#  'md_30_median': 0.19090909090909092,
#  'md_30_min': 0.08181818181818182,
#  'md_30_total': 0.12954545454545455,
#  'md_30_count': 0.029545454545454545,
#  'card_md0_mean': 0.3159090909090909,
#  'card_md0_max': 0.4102272727272727,
#  'card_md0_median': 0.29545454545454547,
#  'card_md0_min': 0.26136363636363635,
#  'card_md0_total': 0.5522727272727272,
#  'card_md0_count': 0.13636363636363635,
#  'card_md1_mean': 0.29659090909090907,
#  'card_md1_max': 0.4511363636363636,
#  'card_md1_median': 0.28863636363636364,
#  'card_md1_min': 0.24659090909090908,
#  'card_md1_total': 0.5920454545454545,
#  'card_md1_count': 0.2215909090909091,
#  'card_md3_mean': 0.29318181818181815,
#  'card_md3_max': 0.4693181818181818,
#  'card_md3_median': 0.28295454545454546,
#  'card_md3_min': 0.2431818181818182,
#  'card_md3_total': 0.6363636363636364,
#  'card_md3_count': 0.22386363636363638,
#  'card_md7_mean': 0.2897727272727273,
#  'card_md7_max': 0.4590909090909091,
#  'card_md7_median': 0.2761363636363636,
#  'card_md7_min': 0.24204545454545454,
#  'card_md7_total': 0.6363636363636364,
#  'card_md7_count': 0.25227272727272726,
#  'card_md14_mean': 0.28863636363636364,
#  'card_md14_max': 0.4693181818181818,
#  'card_md14_median': 0.275,
#  'card_md14_min': 0.23977272727272728,
#  'card_md14_total': 0.6329545454545454,
#  'card_md14_count': 0.27386363636363636,
#  'card_md30_mean': 0.2909090909090909,
#  'card_md30_max': 0.4681818181818182,
#  'card_md30_median': 0.27386363636363636,
#  'card_md30_min': 0.24204545454545454,
#  'card_md30_total': 0.5602272727272727,
#  'card_md30_count': 0.28295454545454546,
#  'cars_ms0_mean': 0.31931818181818183,
#  'cars_ms0_max': 0.41363636363636364,
#  'cars_ms0_median': 0.2988636363636364,
#  'cars_ms0_min': 0.26022727272727275,
#  'cars_ms0_total': 0.5545454545454546,
#  'cars_ms0_count': 0.10909090909090909,
#  'cars_ms1_mean': 0.30113636363636365,
#  'cars_ms1_max': 0.43636363636363634,
#  'cars_ms1_median': 0.29204545454545455,
#  'cars_ms1_min': 0.23977272727272728,
#  'cars_ms1_total': 0.5943181818181819,
#  'cars_ms1_count': 0.18181818181818182,
#  'cars_ms3_mean': 0.30113636363636365,
#  'cars_ms3_max': 0.46704545454545454,
#  'cars_ms3_median': 0.28295454545454546,
#  'cars_ms3_min': 0.225,
#  'cars_ms3_total': 0.6215909090909091,
#  'cars_ms3_count': 0.1375,
#  'cars_ms7_mean': 0.30568181818181817,
#  'cars_ms7_max': 0.48295454545454547,
#  'cars_ms7_median': 0.2875,
#  'cars_ms7_min': 0.2125,
#  'cars_ms7_total': 0.5886363636363636,
#  'cars_ms7_count': 0.04431818181818182,
#  'cars_ms14_mean': 0.3125,
#  'cars_ms14_max': 0.4818181818181818,
#  'cars_ms14_median': 0.29318181818181815,
#  'cars_ms14_min': 0.2034090909090909,
#  'cars_ms14_total': 0.5170454545454546,
#  'cars_ms14_count': 0.02159090909090909,
#  'cars_ms30_mean': 0.325,
#  'cars_ms30_max': 0.4715909090909091,
#  'cars_ms30_median': 0.29659090909090907,
#  'cars_ms30_min': 0.1784090909090909,
#  'cars_ms30_total': 0.43977272727272726,
#  'cars_ms30_count': 0.0,
#  'cars_mz0_mean': 0.31477272727272726,
#  'cars_mz0_max': 0.4102272727272727,
#  'cars_mz0_median': 0.29545454545454547,
#  'cars_mz0_min': 0.26022727272727275,
#  'cars_mz0_total': 0.55,
#  'cars_mz0_count': 0.10909090909090909,
#  'cars_mz1_mean': 0.29659090909090907,
#  'cars_mz1_max': 0.45,
#  'cars_mz1_median': 0.28863636363636364,
#  'cars_mz1_min': 0.24545454545454545,
#  'cars_mz1_total': 0.5909090909090909,
#  'cars_mz1_count': 0.1806818181818182,
#  'cars_mz3_mean': 0.29318181818181815,
#  'cars_mz3_max': 0.4693181818181818,
#  'cars_mz3_median': 0.28295454545454546,
#  'cars_mz3_min': 0.2409090909090909,
#  'cars_mz3_total': 0.6306818181818182,
#  'cars_mz3_count': 0.13863636363636364,
#  'cars_mz7_mean': 0.2909090909090909,
#  'cars_mz7_max': 0.4590909090909091,
#  'cars_mz7_median': 0.2772727272727273,
#  'cars_mz7_min': 0.23977272727272728,
#  'cars_mz7_total': 0.6272727272727273,
#  'cars_mz7_count': 0.03977272727272727,
#  'cars_mz14_mean': 0.2875,
#  'cars_mz14_max': 0.4693181818181818,
#  'cars_mz14_median': 0.27386363636363636,
#  'cars_mz14_min': 0.2375,
#  'cars_mz14_total': 0.6125,
#  'cars_mz14_count': 0.0,
#  'cars_mz30_mean': 0.28863636363636364,
#  'cars_mz30_max': 0.4715909090909091,
#  'cars_mz30_median': 0.2715909090909091,
#  'cars_mz30_min': 0.23522727272727273,
#  'cars_mz30_total': 0.5159090909090909,
#  'cars_mz30_count': 0.0,
#  'dscard': 0.01818181818181818,
#  'dsmerch': 0.010227272727272727,
#  'dsmerchcard': 0.03409090909090909,
#  'dszipcard': 0.05227272727272727,
#  'dsstatecard': 0.028409090909090908,
#  'random': 0.035227272727272725}

# %%
fdrdf = pd.DataFrame.from_dict(fdrdic,orient = 'index')
fdrdf.columns=['FDR']

# %%
fdr_flag = fdrdf.sort_values(by='FDR',ascending=False).reset_index().reset_index()

# %%
fdr_flag['level_0']=fdr_flag['level_0']+1

# %%
#KS and FDR Score
KS_flag1.columns=['KS_RANK','KS','VARIABLE']
fdr_flag.columns=['FDR_RANK','VARIABLE','FDR']

# %%
KS_flag1.to_csv('KS.csv')
fdr_flag.to_csv('FDR.csv')
